# %%
# imports
import pandas as pd

# %%
# only colab environment
#from google.colab import drive  
#drive.mount('/content/drive')
#v_path = '/content/drive/MyDrive/ENERO_23/BENCHMARK/'

# %%
# local environment
v_path = '../'

# %%
# Leemos los ficheros txt exportados de Tradestation para cada activo y lo convertimos a pkl 
nq = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/NQ.txt")
nq.to_pickle('NQ.pkl')
es = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/ES.txt")
es.to_pickle('ES.pkl')
ym = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/YM.txt")
ym.to_pickle('YM.pkl')
cl = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/CL.txt")
cl.to_pickle('CL.pkl')
ng = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/NG.txt")
ng.to_pickle('NG.pkl')
gc = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/GC.txt")
gc.to_pickle('GC.pkl')
#vx = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/VX.txt")
#vx.to_pickle(v_path + 'VX.pkl')
#ty = pd.read_csv(v_path + "HISTORICOS_TRADESTATION_2008_1min__01_01_2023/TY.txt")
#ty.to_pickle(v_path + 'TY.pkl')

# %%
# vemos la estructura que tienen los datos
nq
# Out:
#                Date   Time      Open      High       Low     Close  Vol  OI
# 0        01/02/2008  05:01   2378.75   2380.00   2378.00   2379.50  121  63
# 1        01/02/2008  05:02   2379.50   2380.50   2379.50   2380.50   35  48
# 2        01/02/2008  05:03   2380.75   2381.75   2380.75   2381.25   14  11
# 3        01/02/2008  05:04   2381.00   2381.50   2380.25   2381.00   10  73
# 4        01/02/2008  05:05   2381.00   2381.00   2380.50   2381.00   45   7
# ...             ...    ...       ...       ...       ...       ...  ...  ..
# 4862570  12/30/2022  15:56  11038.75  11039.50  11037.75  11038.00   41  68
# 4862571  12/30/2022  15:57  11037.75  11040.00  11037.50  11040.00   26  58
# 4862572  12/30/2022  15:58  11039.75  11041.50  11039.75  11040.75   27  18
# 4862573  12/30/2022  15:59  11040.50  11040.75  11040.00  11040.25   13  23
# 4862574  12/30/2022  16:00  11039.50  11042.00  11039.25  11041.75   74  53
#
# [4862575 rows x 8 columns]
